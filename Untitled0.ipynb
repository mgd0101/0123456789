# %% [markdown]
# Nvidia ekran kartı CUDA teknolojileri ile sunularda sıkça kulanılır

# %%
# !nvidia-smi
# Out:
# Sat Dec 14 15:08:31 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   62C    P8              11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %% [markdown]
# #Python Giriş Eğitimi
# bu derste print fonksiyonu ile ekrana yazdırma printfonksiyonun temel özelikleri yer almaktadır

# %%
print("SÜTAŞIN DÜNYASI")
# Out:
# SÜTAŞIN DÜNYASI

# %%
print("SÜTAŞIN DÜNYASI")
# Out:
# SÜTAŞIN DÜNYASI

# %%
print(8)
print(12)
print(8+12)
print(8-12)
print(8*12)
print(8/12)
# Out:
# 8
# 12
# 20
# -4
# 96
# 0.6666666666666666

# %% [markdown]
# **Sring:**Metin yazılı değişkenlerine verilen isimdirÇift veya tek tırnak içerisine yazılır

# %%
print(str(8)+""+str(12))
# Out:
# 812

# %% [markdown]
# NOTsayılar metne dönüşür metinler sayılara çevirilmez

# %%
print(len("süüüüüü"))
# Out:
# 7

# %%
print("Atatürk demişki:Egemenlik kayıtsız şartsız miletindir")
# Out:
# Atatürk demişki:Egemenlik kayıtsız şartsız miletindir

# %%
print((8-12),(8+12),(8*12),(8/12))
# Out:
# -4 20 96 0.6666666666666666

# %%
print("bügün","hava","çok","güzel")
# Out:
# bügün hava çok güzel

# %%
print("bügün\n","çok")
# Out:
# bügün
#  çok
