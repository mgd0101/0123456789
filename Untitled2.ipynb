# %% [markdown]
# *Deyişkenler*
# yazılımda içinde veri sakladığımız yapılara deyişkenler diyoruz. Bu veri yazılımcının veya kulanıcının sakladıgı bilgilerdir

# %%
#Bir deyişken oluşturula bilir
# 1. yol
Adsoyad = "müfit Durmuş"
print(Adsoyad)
# 2. yol
Ad = "Müfit"
Soyad = "Durmuş"
print(Ad + " " + Soyad)
# Out:
# müfit Durmuş
# Müfit Durmuş

# %% [markdown]
# # *Deyişken isimini deyişk

# %%
#Deyişkenler türleri
#Bir Arabaın özeliyi
arabamarka = "Mersedes"
arabahiz = 4000
Soyad = "Durmuş"
arabsnınyüksekligi

# %%
araba = "tofaş"
hız = "6000"
genişligi = 380

print(araba, hız, genişligi, sep="\n")
# Out:
# tofaş
# 6000
# 380

# %% [markdown]
# deyişkeleri içindeki değerden bağımsız olarakişleme bağlalayarak işleme sokabiiriz deyişkenleri işleme sokabilmek için yani deyişken oluşturulabilir
# *   Liste öğesi

# %%
sayi1 = 10
sayi2 = 20
toplam = sayi1 + sayi2
print(toplam)
print(sayi1,"+",sayi2,"=",toplam)
# Out:
# 30
# 10 + 20 = 30

# %%
sayi1 = 10
sayi2 = 20
toplam = sayi1 + sayi2
print(toplam)
print(str(sayi1)+"+"+str(sayi2)+"="+str(toplam))
# Out:
# 30
# 10+20=30
